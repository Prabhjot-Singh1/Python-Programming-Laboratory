# %% [markdown]
# # Name:Prabhjot singh
# # Roll no.: 25901343

# %% [markdown]
# 1. Write a Python function find_smallest_multiple(n: int) that uses a while loop to find the smallest
# positive integer x such that x is divisible by all numbers from 1 to n.
# Conditions:
# * i. The function should keep incrementing x by 1 until it finds a number that satisfies the
# condition.
# * ii. Your solution should handle the edge case where n = 1 efficiently, returning 1 directly since 1
# is divisible by itself.

# %%
def find_smallest_multiple(n):
    res=n
    flag = True
    while flag:
        i=1
        cnt = 0
        while i<=n:
            if res%i==0:
                cnt+=1
            i+=1
        if cnt==n:
            print(res)
            flag=False
        res+=1
            
find_smallest_multiple(1)
# Out:
# 1

# %% [markdown]
# Write a function cubesum() that accepts an integer and returns the sum of the cubes of individual digits
# of that number. Use this function to make functions PrintArmstrong() and isArmstrong() to print
# Armstrong numbers and to find whether is an Armstrong number.

# %%
def cubesum(n):
    temp =0
    while n:
        temp+=(n%10)**3
        n//=10
    return temp;

def isArmstrong(n):
    return n== cubesum(n)

def PrintArmstrong(start, end):
    for i in range(start, end +1):
        if isArmstrong(i):
            print(i)

PrintArmstrong(1,10)
n=153
if isArmstrong(n):
    print(f"{n} is Armstrong")
else:
    print(f"{n} is not armstrong")
# Out:
# 1
# 153 is Armstrong

# %% [markdown]
# 3. Why is operator precedence important? Give an example where neglecting precedence changes the
# result.

# %%
print(2+3*10)
print(f"changes when {(2+3)*10}")
# Out:
# 32
# changes when 50

# %% [markdown]
# 4. Write a program to input a decimal number and print its equivalent binary, octal, and hexadecimal
# using operators.

# %%
def to_binary(n):
    s=""
    while n:
        if n&1:
            s+='1'
        else:
            s+='0'
        n>>=1
    return s[::-1]

def dec_to_octal(n):
    octal=''
    while n:
        rem = n%8
        octal = str(rem)+octal 
        n//=8
    return octal

def dec_to_hexadecimal(n):
    hex_chart="0123456789ABCDEF"
    hexa = ''
    while n:
        rem = n%16
        hexa = hex_chart[rem]+hexa
        n//=16
    return hexa

n = int(input())
print(f"decimal to binary {to_binary(n)}")
print(f"decimal to octal of {n} is {dec_to_octal(n)}")
print(f"decimal to hexadecimal of {n} is {dec_to_hexadecimal(n)}")
# Out:
# decimal to binary 11001
# decimal to octal of 25 is 31
# decimal to hexadecimal of 25 is 19

# %% [markdown]
# 5. Write a Python function to create and print a list where the values are the squares of numbers between
# 1 and 30 (both included).

# %%
def square_list():
    sq_List = []
    for i in range(1,31):
        sq_List.append(i**2)
    print(sq_List)
square_list()
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900]

# %% [markdown]
# 6. Write a program that takes a sentence as input and counts the frequency of vowels, consonants, digits,
# and special characters separately

# %%
def count_char(s):
    vowels = "AEIOUaeiou"
    vowel_cnt = 0
    con_cnt=0
    digit_cnt = 0
    special_cnt = 0
    for ch in s:
        if ch.isalpha():
            if ch in vowels:
                vowel_cnt+=1
            else:
                con_cnt+=1
        elif ch.isdigit():
            digit_cnt+=1
        elif not ch.isspace():
            special_cnt+=1

    print(f"Vowels: {vowel_cnt}")
    print(f"Consonants: {con_cnt}")
    print(f"Digits: {digit_cnt}")
    print(f"Special Characters: {special_cnt}")
sentence = input("Enter a sentence: ")
count_char(sentence)
# Out:
# Vowels: 3
# Consonants: 7
# Digits: 3
# Special Characters: 1

# %% [markdown]
# 7. Write a Python program to create a dictionary of students’ names as keys and their marks as values.
# Then:
# A. Print the student with the highest marks
# B. Print the student with the lowest marks

# %%
def student_marks():
    n = int(input("Enter number of student: "))
    students = {}
    for i in range(n):
        name = input(f"Enter name {i+1}")
        marks = float(input(f"enter marks {name}"))
        students[name]=marks
    print("\nStudent Marks Dictionary:")
    print(students)

    highest_student = max(students, key=students.get)
    lowest_student = min(students, key=students.get)

    print(f"\nStudent with highest marks: {highest_student} ({students[highest_student]})")
    print(f"Student with lowest marks: {lowest_student} ({students[lowest_student]})")
student_marks()
# Out:
# Student Marks Dictionary:
# {'bob': 99.0, 'ram': 79.0, 'riya': 89.0}
#
# Student with highest marks: bob (99.0)
# Student with lowest marks: ram (79.0)
